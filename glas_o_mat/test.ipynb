# %%
from glas_o_mat.dataset import load_data, create_dataset

# %%
dataset = load_data()
dataset.activities
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 0                 388  1001101102100921111            20       NaN
# 1                 383  1001101102100861211            10       NaN
# 2                 382  1001101102100861111            30       NaN
# 3                 384  1001101102100861311            60       NaN
# 4                 444  1001101101100251111            10       NaN
# ...               ...                  ...           ...       ...
# 38530           61152  1001101101100531212            90       NaN
# 38531           61149  1001101101100531111            90       NaN
# 38532           61150  1001101101100531112            90       NaN
# 38533           61153  1001101101100531311            20       NaN
# 38534           61154  1001101101100531312            10       NaN
#
#        SENSOR_LEVEL                                           IMAGE_ID  \
# 0               NaN    1001101102100921111/2023-09-28T11:31:15.634.png
# ...

# %%
'''
- koordinaten aus location einfügen
- inaccurate locations behandeln
- distanzen berechnen zwischen koordinaten
- outlier
- temporary shifts
- glätten
'''
