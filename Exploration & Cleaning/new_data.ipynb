# %%
import pandas as pd

# %% [markdown]
# # Locations

# %%
#df_locations_new = pd.read_csv('/Users/annele/Library/CloudStorage/OneDrive-zebrafant.ai/BA/Data/location_export.csv')
df_locations_new = pd.read_csv('/Users/annele/PycharmProjects/Glas-O-Mat/data/Locations.csv')
df_locations_new['LOCATION_ID'] = df_locations_new['LOCATION_ID'].astype(str)
df_locations_new
# Out:
#          LOCATION_ID    GEO_LAT   GEO_LON           LOCATION_NAME  \
# 0       100110110101  49.493983  7.844887  Jakob Becker Mehlingen
# 1       100110110191  49.503797  7.851304              Schirmbeck
# 2       100110110201  49.493983  7.844887  Jakob Becker Mehlingen
# 3       100110110291  49.503797  7.851304              Schirmbeck
# 4       100110210191  -1.000000 -1.000000        Unknown Location
# ..               ...        ...       ...                     ...
# 395  100310110101104  50.258766  9.009344          Recyclinghof A
# 396  100310110101105  52.049840  8.993340       Brandenburger Tor
# 397  100310110101106  51.911000  8.809850                 Theater
# 398  100310110101107  51.110000  8.808500         Einkaufszentrum
# 399  100310110101108  51.100000  8.085000               Cafe Mert
#
#              CITY             STREET POSTALCODE  IS_ACTIVE  \
# 0       Mehlingen     An d. Heide 10      67678          1
# ...

# %%
df_locations_old = pd.read_csv('/Users/annele/Library/CloudStorage/OneDrive-zebrafant.ai/BA/Data/20241017_database_export/Locations.csv')
df_locations_old['LOCATION_ID'] = df_locations_old['LOCATION_ID'].astype(str)
df_locations_old
# Out:
#          LOCATION_ID    GEO_LAT   GEO_LON           LOCATION_NAME  \
# 0       100110110101  49.493983  7.844887  Jakob Becker Mehlingen
# 1       100110110191  49.503797  7.851304              Schirmbeck
# 2       100110110201  49.493983  7.844887  Jakob Becker Mehlingen
# 3       100110110291  49.503797  7.851304              Schirmbeck
# 4       100110210191  -1.000000 -1.000000        Unknown Location
# ..               ...        ...       ...                     ...
# 395  100310110101104  50.258766  9.009344          Recyclinghof A
# 396  100310110101105  52.049840  8.993340       Brandenburger Tor
# 397  100310110101106  51.911000  8.809850                 Theater
# 398  100310110101107  51.110000  8.808500         Einkaufszentrum
# 399  100310110101108  51.100000  8.085000               Cafe Mert
#
#              CITY             STREET POSTALCODE  IS_ACTIVE  \
# 0       Mehlingen     An d. Heide 10      67678          1
# ...

# %%
# show the location ids that are in the new data but not in the old data
df_locations_new[~df_locations_new['LOCATION_ID'].isin(df_locations_old['LOCATION_ID'])]
# Out:
# Empty DataFrame
# Columns: [LOCATION_ID, GEO_LAT, GEO_LON, LOCATION_NAME, CITY, STREET, POSTALCODE, IS_ACTIVE, DISPOSITION_AREA_ID, ACCESS_TYPE, HAS_POSITION_CHANGED]
# Index: []

# %%
# show the location ids that are in the old data but not in the new data
df_locations_old[~df_locations_old['LOCATION_ID'].isin(df_locations_new['LOCATION_ID'])]
# Out:
# Empty DataFrame
# Columns: [LOCATION_ID, GEO_LAT, GEO_LON, LOCATION_NAME, CITY, STREET, POSTALCODE, IS_ACTIVE, DISPOSITION_AREA_ID, ACCESS_TYPE, HAS_POSITION_CHANGED]
# Index: []

# %%
'''
Location csv file from 20241017_database_export is the same as the location_export.csv file.
'''
# Out:
# '\nLocation csv file from 20241017_database_export is the same as the location_export.csv file.\n'

# %% [markdown]
# # Activities

# %%
df_activities = pd.read_csv('/Users/annele/Library/CloudStorage/OneDrive-zebrafant.ai/BA/Data/activities_export.csv')
df_activities
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 0                   2  1001101101100271211            20       NaN
# 1                   1  1001101101100271111            30       NaN
# 2                   3  1001101101100271311            10       NaN
# 3                   6  1001101101100191311            10       NaN
# 4                   4  1001101101100191111             0       NaN
# ...               ...                  ...           ...       ...
# 41458           61152  1001101101100531212            90       NaN
# 41459           61149  1001101101100531111            90       NaN
# 41460           61150  1001101101100531112            90       NaN
# 41461           61153  1001101101100531311            20       NaN
# 41462           61154  1001101101100531312            10       NaN
#
#        SENSOR_LEVEL                                           IMAGE_ID  \
# 0               NaN  1001101101100271211/2023-09-28T06:36:05.355751...
# ...

# %%
'''
Less data points (45) because data points from the demo phone ('TKQ1') were removed.
'''
# Out:
# "\nLess data points (45) because data points from the demo phone ('TKQ1') were removed.\n"
