# %%
import numpy as np
import pandas as pd

from glas_o_mat import dataset as ds

# %%
dataset = ds.create_dataset()

dataset.activities
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 0                   2  1001101101100271211            20       NaN
# 1                   1  1001101101100271111            30       NaN
# 2                   3  1001101101100271311            10       NaN
# 3                   6  1001101101100191311            10       NaN
# 4                   4  1001101101100191111             0       NaN
# ...               ...                  ...           ...       ...
# 41458           61152  1001101101100531212            90       NaN
# 41459           61149  1001101101100531111            90       NaN
# 41460           61150  1001101101100531112            90       NaN
# 41461           61153  1001101101100531311            20       NaN
# 41462           61154  1001101101100531312            10       NaN
#
#        SENSOR_LEVEL                                           IMAGE_ID  \
# 0               NaN  1001101101100271211/2023-09-28T06:36:05.355751...
# ...

# %%
locations = dataset.activities.groupby(['LOCATION_ID', 'MATERIAL_ID'])
g = locations.get_group((100110110110020, 13)).drop_duplicates(['DATE', 'CONTAINER_ID'])
g[g['DATE'] >= '2024-05-06']
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 22611           28115  1001101101100201311            40       NaN
# 22612           28116  1001101101100201312            30       NaN
# 22613           28117  1001101101100201313            40       NaN
# 23229           28768  1001101101100201311            80       NaN
# 23230           28769  1001101101100201312            30       NaN
# 24886           30452  1001101101100201311            30       NaN
# 24887           30453  1001101101100201312            30       NaN
# 25769           31350  1001101101100201311            70       NaN
# 25770           31351  1001101101100201312            40       NaN
# 26735           32314  1001101101100201311            90       NaN
# 26736           32315  1001101101100201312            30       NaN
# 27407           32975  1001101101100201311            30       NaN
# 27408           32976  1001101101100201312            80       NaN
# ...

# %%
dataset.locations
# Out:
#          LOCATION_ID    GEO_LAT   GEO_LON           LOCATION_NAME  \
# 0       100110110101  49.493983  7.844887  Jakob Becker Mehlingen
# 1       100110110191  49.503797  7.851304              Schirmbeck
# 2       100110110201  49.493983  7.844887  Jakob Becker Mehlingen
# 3       100110110291  49.503797  7.851304              Schirmbeck
# 4       100110210191  -1.000000 -1.000000        Unknown Location
# ..               ...        ...       ...                     ...
# 395  100310110101104  50.258766  9.009344          Recyclinghof A
# 396  100310110101105  52.049840  8.993340       Brandenburger Tor
# 397  100310110101106  51.911000  8.809850                 Theater
# 398  100310110101107  51.110000  8.808500         Einkaufszentrum
# 399  100310110101108  51.100000  8.085000               Cafe Mert
#
#              CITY             STREET POSTALCODE  IS_ACTIVE  \
# 0       Mehlingen     An d. Heide 10      67678          1
# ...

# %%
merged = pd.merge(dataset.activities, dataset.locations, on='LOCATION_ID', how='left')
merged
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19596\2439976565.py in ?()
# ----> 1 merged = pd.merge(dataset.activities, dataset.locations, on=['LOCATION_ID', 'MATERIAL_ID'], how='left')
#       2 merged
#
# ~\miniconda3\envs\glas-o-mat\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\miniconda3\envs\glas-o-mat\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
# ...

# %%
merged[merged['GEO_LAT'].isna()]
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 14375           19911      100110199991311            30       NaN
# 14376           19882      100110199991111            20       NaN
# 14377           19910      100110199991211            20       NaN
# 37774           57439     1001101102001211            20       NaN
# 37775           57438     1001101102001111            50       NaN
# 37776           57440     1001101102001311            50       NaN
# 38044           57713     1002101101001211            80       NaN
# 38045           57711     1002101101001111            60       NaN
# 38046           57712     1002101101001112            60       NaN
# 38414           58089     1002101101001111            70       NaN
# 38415           58091     1002101101001311           100       NaN
# 38416           58090     1002101101001211            30       NaN
# 38457           58132     1002101101001311            60       NaN
# ...

# %%
containers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 containers
#
# NameError: name 'containers' is not defined

# %%
t = dataset.activities.copy()
t[(t['LOCATION_ID'] == 100110110110038)]
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 72                103  1001101101100381311            10       NaN
# 73                101  1001101101100381111            20       NaN
# 74                102  1001101101100381211            10       NaN
# 981              2028  1001101101100381311            10       NaN
# 982              2026  1001101101100381111            10       NaN
# ...               ...                  ...           ...       ...
# 39525           59213  1001101101100381111            40       NaN
# 39526           59214  1001101101100381211            20       NaN
# 41439           61133  1001101101100381311            70       NaN
# 41440           61131  1001101101100381111            60       NaN
# 41441           61132  1001101101100381211            40       NaN
#
#        SENSOR_LEVEL                                           IMAGE_ID  \
# 72              NaN  1001101101100381311/2023-09-28T11:40:41.820991...
# ...

# %%
filter = dataset.locations.groupby('LOCATION_ID').median()
filter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\miniconda3\envs\glas-o-mat\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\miniconda3\envs\glas-o-mat\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\miniconda3\envs\glas-o-mat\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
import pandas as pd
activities = pd.read_csv('../data/ContainerActivities.csv')
activities['PHONE_ID'] = activities['PHONE_ID'].astype(str)
activities[activities['PHONE_ID'].str.startswith('TKQ1')]
# Out:
#        TRANSACTION_ID         CONTAINER_ID  SLIDER_LEVEL  CV_LEVEL  \
# 2344             4629  1001101102101211211            80       NaN
# 2345             4630  1001101102101211111           100       NaN
# 2368             4746  1001101102101211111            40       NaN
# 2369             4748  1001101102101211211           110       NaN
# 2370             4749  1001101102101211311           110       NaN
# 2594             5122  1001101101999991311            80       NaN
# 2609             5147  1001101101999991211            90       NaN
# 2610             5148  1001101101999991211            90       NaN
# 2611             5149  1001101102101211111            20       NaN
# 2612             5150  1001101102101211211            80       NaN
# 2613             5151  1001101102101211311            50       NaN
# 6436             9477  1001101102101211111            10       NaN
# 6437             9478  1001101102101211211            50       NaN
# ...

# %% [markdown]
# ### TODO: drop rows which are recorded in an interval which is to close
